# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from MDParser import AnalysisParser

sns.set_style('darkgrid')

# %%
def plotForDenoiser(analysisData, variable, denoiser):

    sigmas = list(sorted(analysisData[0].keys()))
    values = []
    for sigma in sigmas:
        if denoiser == 'KF' and sigma==3:
            values.append(analysisData[0][sigma-0.1][denoiser][variable])
        else:
            values.append(analysisData[0][sigma][denoiser][variable])

    plt.plot(sigmas, values)
    plt.xlabel("σ")
    plt.xticks(sigmas, rotation=90)
    plt.ylabel(variable)

# %%
parser = AnalysisParser()

# %% [markdown]
# ### Model 4

# %%
analysisDataModel1 = parser.parseAnalysisData('../SBAgent/models/base/model4/best_model.zip_eval.md_unbiased.md')

plotForDenoiser(analysisDataModel1, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel1, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()

# %% [markdown]
# ### Model 5

# %%
analysisDataModel2 = parser.parseAnalysisData('../SBAgent/models/base/model5/best_model.zip_eval.md_unbiased.md')

plotForDenoiser(analysisDataModel2, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel2, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()

# %% [markdown]
# ### Model 6

# %%
analysisDataModel3 = parser.parseAnalysisData('../SBAgent/models/base/model6/best_model.zip_eval.md_unbiased.md')


plotForDenoiser(analysisDataModel3, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel3, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()

# %% [markdown]
# ### Model 1

# %%
analysisDataModel2 = parser.parseAnalysisData('../SBAgent/evalResults/model1/unbiased.md')

plotForDenoiser(analysisDataModel2, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel2, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()

# %% [markdown]
# ### Model 2

# %%
analysisDataModel2 = parser.parseAnalysisData('../SBAgent/evalResults/model2/unbiased.md')

plotForDenoiser(analysisDataModel2, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel2, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()

# %% [markdown]
# ### Model 3

# %%
analysisDataModel2 = parser.parseAnalysisData('../SBAgent/evalResults/model3/unbiased.md')

plotForDenoiser(analysisDataModel2, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel2, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()

# %% [markdown]
# ### Model 4 tested on static+dynamic environment

# %%
analysisDataModel1 = parser.parseAnalysisData('../SBAgent/evalResults/model4_static/unbiased.md')

plotForDenoiser(analysisDataModel1, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel1, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()

# %% [markdown]
# ### Model 5 on stationary+dynamic environment

# %%
analysisDataModel1 = parser.parseAnalysisData('../SBAgent/evalResults/model5_static/unbiased.md')

plotForDenoiser(analysisDataModel1, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel1, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()

# %% [markdown]
# ### Model 6 on Static+dynamic environment

# %%
analysisDataModel1 = parser.parseAnalysisData('../SBAgent/evalResults/model6_static/unbiased.md')

plotForDenoiser(analysisDataModel1, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([0,1])
plt.xticks(np.arange(0,3.1,0.2))
plt.show()

plotForDenoiser(analysisDataModel1, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim([-6000,-500])
plt.show()
