# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from MDParser import AnalysisParser

sns.set_style('darkgrid')

# %%
def plotForDenoiser(analysisData, variable, denoiser):

    mus = list(sorted(analysisData.keys()))
    values = []
    for mu in mus:
        values.append(analysisData[mu][0][denoiser][variable])

    plt.plot(mus, values)
    plt.xlabel("μ")
    plt.xticks(mus, rotation=90)
    plt.ylabel(variable)

# %%
parser = AnalysisParser()

# %% [markdown]
# ### Model 1

# %%
analysisDataModel1 = parser.parseAnalysisData('../SBAgent/evalResults/model1/biased.md')

plotForDenoiser(analysisDataModel1, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel1, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim(0,1)
plt.xticks(np.arange(0,0.31,0.02))
plt.show()

plt.title("Mean Reward for Model1 (No Noise During Training)")
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel1, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.show()

# %% [markdown]
# ### Model 2

# %%
analysisDataModel2 = parser.parseAnalysisData('../SBAgent/evalResults/model2/biased.md')

plotForDenoiser(analysisDataModel2, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel2, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim(0,1)
plt.xticks(np.arange(0,0.31,0.02))
plt.show()

plt.title("Mean Reward for Model2 (0.1 STD Noise During Training)")
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel2, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.show()

# %% [markdown]
# ### Model 3

# %%
analysisDataModel3 = parser.parseAnalysisData('../SBAgent/evalResults/model3/biased.md')

plotForDenoiser(analysisDataModel3, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.ylim(0,1)
plt.xticks(np.arange(0,0.31,0.02))
plt.show()

plt.title("Mean Reward for Model3 (1.0 STD Noise During Training)")
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.show()

# %% [markdown]
# ### Model 4

# %%
analysisDataModel3 = parser.parseAnalysisData('../SBAgent/models/best_model.zip_eval.md_biased.md')


plotForDenoiser(analysisDataModel3, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'KF')
plt.ylim(0,1)
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.xticks(np.arange(0,0.31,0.02))
plt.show()


plotForDenoiser(analysisDataModel3, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.show()

# %% [markdown]
# ### Model 5

# %%
analysisDataModel3 = parser.parseAnalysisData('../SBAgent/best_model.zip_eval.md_biased.md')

plotForDenoiser(analysisDataModel3, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'KF')
plt.ylim(0,1)
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.xticks(np.arange(0,0.31,0.02))
plt.show()

plotForDenoiser(analysisDataModel3, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 analysisDataModel3 = parser.parseAnalysisData('../SBAgent/best_model.zip_eval.md_biased.md')
#       3 plotForDenoiser(analysisDataModel3, 'Success Rate', 'None')
#       4 plotForDenoiser(analysisDataModel3, 'Success Rate', 'LPF')
#
# File ~/DroneControl/visualizations/MDParser.py:10, in AnalysisParser.parseAnalysisData(self, filePath)
#       9 def parseAnalysisData(self, filePath):
# ---> 10     with open(filePath) as f:
#      11         lines = f.readlines()
#      13     self.content = ''.join(lines)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../SBAgent/best_model.zip_eval.md_biased.md'

# %% [markdown]
# ### Model 6

# %%
analysisDataModel3 = parser.parseAnalysisData('../SBAgent/models/base/model6/best_model.zip_eval.md_biased.md')


plotForDenoiser(analysisDataModel3, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'KF')
plt.ylim(0,1)
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.xticks(np.arange(0,0.31,0.02))
plt.show()


plotForDenoiser(analysisDataModel3, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.show()

# %% [markdown]
# ### Model 4 on static-dynamic environments

# %%
analysisDataModel3 = parser.parseAnalysisData('../SBAgent/evalResults/model4_static/biased.md')


plotForDenoiser(analysisDataModel3, 'Success Rate', 'None')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'LPF')
plotForDenoiser(analysisDataModel3, 'Success Rate', 'KF')
plt.ylim(0,1)
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.xticks(np.arange(0,0.31,0.02))
plt.show()


plotForDenoiser(analysisDataModel3, 'Mean Reward', 'None')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'LPF')
plotForDenoiser(analysisDataModel3, 'Mean Reward', 'KF')
plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 6
#       4 plotForDenoiser(analysisDataModel3, 'Success Rate', 'None')
#       5 plotForDenoiser(analysisDataModel3, 'Success Rate', 'LPF')
# ----> 6 plotForDenoiser(analysisDataModel3, 'Success Rate', 'KF')
#       7 plt.ylim(0,1)
#       8 plt.legend(["No Denoiser", "LPF", "KF"], frameon=False)
#
# Cell In[2], line 6, in plotForDenoiser(analysisData, variable, denoiser)
#       4 values = []
#       5 for mu in mus:
# ----> 6     values.append(analysisData[mu][0][denoiser][variable])
#       8 plt.plot(mus, values)
#       9 plt.xlabel("μ")
#
# KeyError: 'KF'
